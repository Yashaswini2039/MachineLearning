# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("//content//Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data['Species'] = data['Species'].astype('category')
data['Species'] = data['Species'].cat.codes
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
data = ((data - data.min()) / (data.max() - data.min())) * 9 + 1

# %%
data.describe ()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean     5.500000       4.858333      4.952500       5.208136      5.120000
# std      2.624217       2.070165      1.625979       2.691489      2.861853
# min      1.000000       1.000000      1.000000       1.000000      1.000000
# 25%      3.250000       3.000000      4.000000       1.915254      1.750000
# 50%      5.500000       4.750000      4.750000       6.110169      5.500000
# 75%      7.750000       6.250000      5.875000       7.254237      7.375000
# max     10.000000      10.000000     10.000000      10.000000     10.000000
#
#           Species
# count  150.000000
# mean     5.500000
# std      3.686544
# min      1.000000
# 25%      1.000000
# 50%      5.500000
# 75%     10.000000
# max     10.000000
